# %%
# !pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.8.2-py3-none-any.whl (106 kB)
#      |████████████████████████████████| 106 kB 839 kB/s eta 0:00:01
# Collecting soupsieve>=1.2
#   Downloading soupsieve-1.9.5-py2.py3-none-any.whl (33 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.8.2 soupsieve-1.9.5

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup("<p>Some<b>bad<i>HTML")
soup.find(text="bad")
# Out:
# 'bad'

# %%
url='https://ausopen.com/match/2020-dominic-thiem-vs-novak-djokovic-ms701#!stats'

# %%
soup = BeautifulSoup(url)
# Out:
# /Users/098765T/Desktop/Andriy/Tanya/lib/python3.7/site-packages/bs4/__init__.py:389: UserWarning: "https://ausopen.com/match/2020-dominic-thiem-vs-novak-djokovic-ms701#!stats" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
# !pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.22.0-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 40 kB/s eta 0:00:0101
# Collecting chardet<3.1.0,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 50 kB/s eta 0:00:01
# Collecting idna<2.9,>=2.5
#   Downloading idna-2.8-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 120 kB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2019.11.28-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 326 kB/s eta 0:00:01
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.8-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 75 kB/s eta 0:00:01
# Installing collected packages: chardet, idna, certifi, urllib3, requests
# Successfully installed certifi-2019.11.28 chardet-3.0.4 idna-2.8 requests-2.22.0 urllib3-1.25.8

# %%
import requests

# %%
r = requests.get(url = url)

# %%
r
# Out:
# <Response [200]>

# %%
dir(r)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
r.content
# Out:
# b'\n<!DOCTYPE html>\n<html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">\n\n<head>\n    <script>\n        dataLayer = [];\n    </script>\n\n        <script>\n        (function() {\n            var check = document.createElement(\'script\');\n            if (!(\'noModule\' in check) && \'onbeforeload\' in check) {\n                var support = false;\n                document.addEventListener(\'beforeload\', function(e) {\n                    if (e.target === check) {\n                        support = true;\n                    } else if (!e.target.hasAttribute(\'nomodule\') || !support) {\n                        return;\n                    }\n                    e.preventDefault();\n                }, true);\n\n                check.type = \'module\';\n                check.src = \'.\';\n                document.head.appendChild(check);\n                check.remove();\n            }\n        }());\n    </script>\n\n\n    <script>\n        window.assetBase = "https://ausopen.com/themes/custom/ausopen_official/";\n                window.ablyKey = "FgF2dA.W50N_g:Bw9S5NmJsZxCnJ4v";\n                window.site = "AusOpen";\n        window.sect = "match/2020-dominic-thiem-vs-novak-djokovic-ms701";\n                window.ptype = "match";\n                window.dtype = "";\n                window.scoringApiEndpoint = "https://prod-scores-api.ausopen.com/year/{year}/period/{period}/day/{day}/schedule";\n                        window.rolexLeaderboardIframeUrl = "https://static.rolex.com/clocks/2020/ao_match_schedule_HTML_320x90/rolex.html";\n            </script>\n\n    <meta charset="utf-8" /><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"11e498b9f6",applicationID:"70701621"};window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var i=n[t]={exports:{}};e[t][0].call(i.exports,function(n){var i=e[t][1][n];return r(i||n)},i,i.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<t.length;i++)r(t[i]);return r}({1:[function(e,n,t){function r(){}function i(e,n,t){return function(){return o(e,[u.now()].concat(f(arguments)),n?null:this,t),n?void 0:this}}var o=e("handle"),a=e(4),f=e(5),c=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",d=l+"ixn-";a(p,function(e,n){s[n]=i(l+n,!0,"api")}),s.addPageAction=i(l+"addPageAction",!0),s.setCurrentRouteName=i(l+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,i="function"==typeof n;return o(d+"tracer",[u.now(),e,t],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],t),i)try{return n.apply(this,arguments)}catch(e){throw c.emit("fn-err",[arguments,this,e],t),e}finally{c.emit("fn-end",[u.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=i(d+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),o("err",[e,u.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){var t=e.getEntries();t.forEach(function(e){"first-paint"===e.name?c("timing",["fp",Math.floor(e.startTime)]):"first-contentful-paint"===e.name&&c("timing",["fcp",Math.floor(e.startTime)])})}function i(e,n){var t=e.getEntries();t.length>0&&c("lcp",[t[t.length-1]])}function o(e){if(e instanceof s&&!l){var n,t=Math.round(e.timeStamp);n=t>1e12?Date.now()-t:u.now()-t,l=!0,c("timing",["fi",t,{type:e.type,fid:n}])}}if(!("init"in NREUM&&"page_view_ti ...

# %%
soup = BeautifulSoup(r.content)

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #main-menu
# /
#
# /draws
# /results
# /players
# /event-stats
# /tournament-info
#
# /news
# /ao-radio
#
# /hospitality
# /travel-packages
# https://www.australianopenshop.com/
# /tickets
# #
#
# /draws
# /results
# /players
# /event-stats
# /tournament-info
#
# /news
# /ao-radio
#
# /hospitality
# /travel-packages
# https://www.australianopenshop.com/
# /tickets
# #!?g=video-153706-65357
# /articles/features/back-brink-djokovic-relies-on-mental-edge
# /articles/features/novak-edges-closer-pinnacle
# /articles/features/i-hope-i-win-my-maiden-slam-when-theyre-still-around-thiem-on-big-three
# #!media?g=video-153706
# /articles/features/djokovic-makes-tweaks-extend-melbourne-run
# #!media?g=video-153451
# /articles/features/final-step-could-thiems-time-be-nigh
# /articles/features/day-14-preview-master-v-apprentice-mens-final
# https://ausopen.com/
# https://www.tennis.com.au/
# /broadcasters
# /contact-us
# https://www.tennis.com.au/privacy
# https://www.tennis.com.au/privacy-statement
# https://www.tennis.com.au/conditions-of-use
# /grand
# https://www.tennis.com.au/about-tennis-australia/employment
# https://media.ausopen.com/
# /history
# /partners
# https://www.facebook.com/AustralianOpen
# https://www.instagram.com/australianopen/
# https://twitter.com/australianopen
# https://www.youtube.com/user/australianopentv

# %%
soup.select(".mc-stats-table")
# Out:
# []

# %%
# !pip install -U selenium
# Out:
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
#      |████████████████████████████████| 904 kB 848 kB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: urllib3 in ./Tanya/lib/python3.7/site-packages (from selenium) (1.25.8)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
