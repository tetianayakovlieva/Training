# %%
import pandas as pd

# %%
train = pd.read_csv('cs-training.csv')

# %%
train
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1                 1                              0.766127
# 1                2                 0                              0.957151
# 2                3                 0                              0.658180
# 3                4                 0                              0.233810
# 4                5                 0                              0.907239
# ...            ...               ...                                   ...
# 149995      149996                 0                              0.040674
# 149996      149997                 0                              0.299745
# 149997      149998                 0                              0.246044
# 149998      149999                 0                              0.000000
# 149999      150000                 0                              0.850283
#
# ...

# %%
target = train['SeriousDlqin2yrs']
target
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 149995    0
# 149996    0
# 149997    0
# 149998    0
# 149999    0
# Name: SeriousDlqin2yrs, Length: 150000, dtype: int64

# %%
target.mean()
# Out:
# 0.06684

# %%
test = pd.read_csv('cs-test.csv')
test.head(10)
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1               NaN                              0.885519   43
# 1           2               NaN                              0.463295   57
# 2           3               NaN                              0.043275   59
# 3           4               NaN                              0.280308   38
# 4           5               NaN                              1.000000   27
# 5           6               NaN                              0.509791   63
# 6           7               NaN                              0.587778   50
# 7           8               NaN                              0.046149   79
# 8           9               NaN                              0.013527   68
# 9          10               NaN                              1.000000   23
#
#    NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                     0     0.177513         5700.0
# ...

# %%
test
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1               NaN                              0.885519
# 1                2               NaN                              0.463295
# 2                3               NaN                              0.043275
# 3                4               NaN                              0.280308
# 4                5               NaN                              1.000000
# ...            ...               ...                                   ...
# 101498      101499               NaN                              0.282653
# 101499      101500               NaN                              0.922156
# 101500      101501               NaN                              0.081596
# 101501      101502               NaN                              0.335457
# 101502      101503               NaN                              0.441842
#
# ...

# %%
train[['age', 'NumberOfDependents','MonthlyIncome']]
# Out:
#         age  NumberOfDependents  MonthlyIncome
# 0        45                 2.0         9120.0
# 1        40                 1.0         2600.0
# 2        38                 0.0         3042.0
# 3        30                 0.0         3300.0
# 4        49                 0.0        63588.0
# ...     ...                 ...            ...
# 149995   74                 0.0         2100.0
# 149996   44                 2.0         5584.0
# 149997   58                 0.0            NaN
# 149998   30                 0.0         5716.0
# 149999   64                 0.0         8158.0
#
# [150000 rows x 3 columns]

# %%
LG.train(train[['age', 'NumberOfDependents','MonthlyIncome']].values, target.values)

# %%
pred = LG.predict(test[['age', 'NumberOfDependents','MonthlyIncome']].values)

# %%
li = [[ 1,2,3] , [4,5,6]]
li
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
li[1][1]
# Out:
# 5

# %%
import numpy as np

np_li = np.array(li)

# %%
np_li
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np_li[1,1]
# Out:
# 5

# %%
li[1,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-71fd3cbc42c2> in <module>
# ----> 1 li[1,1]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
li.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-188f96ee0926> in <module>
# ----> 1 li.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
np_li.shape
# Out:
# (2, 3)

# %%
target
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 149995    0
# 149996    0
# 149997    0
# 149998    0
# 149999    0
# Name: SeriousDlqin2yrs, Length: 150000, dtype: int64

# %%
target.values
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
type(target)
# Out:
# pandas.core.series.Series

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
type(li)
# Out:
# list

# %%
type(np_li)
# Out:
# numpy.ndarray

# %%
target.isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 149995    False
# 149996    False
# 149997    False
# 149998    False
# 149999    False
# Name: SeriousDlqin2yrs, Length: 150000, dtype: bool

# %%
train
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1                 1                              0.766127
# 1                2                 0                              0.957151
# 2                3                 0                              0.658180
# 3                4                 0                              0.233810
# 4                5                 0                              0.907239
# ...            ...               ...                                   ...
# 149995      149996                 0                              0.040674
# 149996      149997                 0                              0.299745
# 149997      149998                 0                              0.246044
# 149998      149999                 0                              0.000000
# 149999      150000                 0                              0.850283
#
# ...

# %%
train['SeriousDlqin2yrs']
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 149995    0
# 149996    0
# 149997    0
# 149998    0
# 149999    0
# Name: SeriousDlqin2yrs, Length: 150000, dtype: int64

# %%
target.index
# Out:
# RangeIndex(start=0, stop=150000, step=1)

# %%
target.values
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
target.name
# Out:
# 'SeriousDlqin2yrs'

# %%
type(target)
# Out:
# pandas.core.series.Series

# %%
train.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  150000.000000     150000.000000                         150000.000000
# mean    75000.500000          0.066840                              6.048438
# std     43301.414527          0.249746                            249.755371
# min         1.000000          0.000000                              0.000000
# 25%     37500.750000          0.000000                              0.029867
# 50%     75000.500000          0.000000                              0.154181
# 75%    112500.250000          0.000000                              0.559046
# max    150000.000000          1.000000                          50708.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  150000.000000                         150000.000000  150000.000000
# mean       52.295207                              0.421033     353.005076
# ...

# %%
train['MonthlyIncome']
# Out:
# 0          9120.0
# 1          2600.0
# 2          3042.0
# 3          3300.0
# 4         63588.0
#            ...
# 149995     2100.0
# 149996     5584.0
# 149997        NaN
# 149998     5716.0
# 149999     8158.0
# Name: MonthlyIncome, Length: 150000, dtype: float64

# %%
train['MonthlyIncome'].isnull().sum()
# Out:
# 29731

# %%
train_drop_na = train.dropna()

# %%
len(train_drop_na)
# Out:
# 120269

# %%
train
# Out:
#         Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0                1                 1                              0.766127
# 1                2                 0                              0.957151
# 2                3                 0                              0.658180
# 3                4                 0                              0.233810
# 4                5                 0                              0.907239
# ...            ...               ...                                   ...
# 149995      149996                 0                              0.040674
# 149996      149997                 0                              0.299745
# 149997      149998                 0                              0.246044
# 149998      149999                 0                              0.000000
# 149999      150000                 0                              0.850283
#
# ...

# %%
"""
    train model on 100.000
    
    50.000 we have true labels it our validation dataset
    predictions for 50.000 from model
    
    classification_report, confusion matix. 
    
    150.000 - > 100.000 + 50.000  sklearn 
    
    train_X, train_y, valid_X, valid_y_true_labels = train_test_split(train, target)
    
    print(train_X.shape)
    print(train_y.shape)
    
    model.train( train_X, train_y ) // 100.000
    
    valid_pred = model.predict( valid_X )
    
    confusion_matrix(valid_y_true_labels, valid_pred)
    classification_report(valid_y_true_labels, valid_pred)
"""
